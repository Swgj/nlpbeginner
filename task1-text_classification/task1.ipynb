# %%
import csv
from bow import Bow
from n_gram import N_Gram
import utils

# %% [markdown]
# 没考虑数据不平衡的问题
# 数据集太多，内存放不下

# %%
#读取文件
train_filepath = "../data/sentiment-analysis-on-movie-reviews/train.tsv"
test_filepath = "../data/sentiment-analysis-on-movie-reviews/test.tsv"

with open(train_filepath)as f:
    fread = csv.reader(f,delimiter='\t')
    data = list(fread)

#去掉表头
data = data[1:]
len(data)
# Out:
# 156060

# %%
bow_model = Bow(data,10000)
bow_model.get_words()
bow_model.get_matrix()

# %%
n_gram_model = N_Gram(data,n=2,max_size=10000)
n_gram_model.get_words()
n_gram_model.get_matrix()

# %%
utils.alpha_gradient_plot(bow_model,n_gram_model,10000,10)
# Out:
# 0.21514285714285714 0.23133333333333334
# 0.275 0.25566666666666665
# 0.4208571428571429 0.33766666666666667
# 0.5764285714285714 0.43833333333333335
# 0.5357142857142857 0.394
# 0.5752857142857143 0.439
# 0.5368571428571428 0.36733333333333335
# 0.5908571428571429 0.451
# 0.1997142857142857 0.20266666666666666
# 0.20042857142857143 0.21466666666666667
# 0.20157142857142857 0.21033333333333334
# 0.1772857142857143 0.17733333333333334
# 0.19914285714285715 0.20833333333333334
# 0.3152857142857143 0.291
# 0.443 0.43
# 0.48428571428571426 0.443
# 0.2067142857142857 0.2
# 0.204 0.21366666666666667
# 0.21685714285714286 0.21566666666666667
# 0.2092857142857143 0.21666666666666667
# 0.21857142857142858 0.214
# 0.22428571428571428 0.232
# 0.24342857142857144 0.24166666666666667
# 0.243 0.251
# 0.2087142857142857 0.21033333333333334
# 0.2695714285714286 0.25566666666666665
# 0.47185714285714286 0.3546666666666667
# 0.6212857142857143 0.43833333333333335
# 0.6321428571428571 0.475
# ...
